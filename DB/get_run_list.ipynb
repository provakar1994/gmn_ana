# %%
import pandas as pd

# %% [markdown]
# ## LH2 runs

# %%
df_lh2 = pd.read_csv('good_runList_GMn_nTPE_LH2_pass_2.csv')

# %%
# Convert each run number to a string
str_lh2 = map(str, df_lh2['runnum'])
# Format correctly for bash arrays
print(' '.join(str_lh2))
# Out:
# 11436 11500 11547 11548 11573 11587 11588 11589 11590 11592 11989 11990 11991 11992 11993 11994 12000 12008 12022 12035 12049 12052 12053 12058 12064 12072 12313 12320 12335 12336 12340 12345 12355 12358 12363 12367 12368 12369 12370 12380 12382 12400 12401 12414 12415 12427 12428 12429 12471 12472 12491 12496 12497 12524 12525 12526 12548 12561 12563 12575 12576 12587 12588 12625 12626 12657 12658 12675 12676 12677 12691 12692 12704 12705 12716 12730 12731 12747 12758 12765 12776 12777 12809 12810 12812 12822 12823 12895 12910 12923 12930 12931 12959 12960 12973 12974 13027 13028 13041 13042 13043 13056 13057 13239 13240 13241 13242 13243 13244 13312 13313 13320 13321 13345 13346 13348 13349 13351 13352 13375 13376 13377 13378 13379 13396 13397 13405 13450 13451 13452 13459 13460 13461 13463 13464 13465 13466 13482 13483 13484 13485 13486 13487 13488 13489 13490 13537 13538 13539 13540 13541 13542 13543 13573 13574 13575 13576 13577 13578 13580 13656 13657 13663 13676 13683 13696 13
# ...

# %% [markdown]
# ## LD2 runs

# %%
df_ld2 = pd.read_csv('good_runList_GMn_nTPE_LD2_pass_2.csv')

# %%
# Convert each run number to a string
str_ld2 = map(str, df_ld2['runnum'])
# Format correctly for bash arrays
print(' '.join(str_ld2))
# Out:
# 11449 11451 11452 11456 11493 11494 11495 11496 11551 11554 11562 11563 11564 11565 11568 11570 11571 11579 11580 11581 11582 11583 11586 11593 11594 11595 11996 11997 11998 11999 12001 12002 12004 12006 12013 12014 12017 12019 12021 12029 12030 12038 12039 12040 12041 12042 12043 12044 12045 12046 12047 12048 12050 12051 12055 12056 12057 12059 12060 12062 12063 12065 12066 12068 12069 12070 12071 12073 12314 12315 12316 12318 12319 12321 12322 12323 12333 12337 12338 12339 12341 12342 12343 12344 12346 12347 12348 12349 12356 12357 12359 12360 12362 12364 12366 12371 12372 12373 12374 12375 12376 12377 12378 12379 12383 12384 12385 12387 12388 12394 12395 12396 12403 12404 12405 12406 12407 12408 12409 12410 12411 12412 12416 12423 12424 12425 12473 12474 12478 12479 12480 12481 12482 12485 12486 12498 12499 12500 12501 12502 12512 12513 12514 12515 12516 12517 12521 12523 12527 12532 12534 12535 12536 12537 12538 12539 12541 12542 12543 12544 12547 12549 12550 12551 12552 12553 12
# ...

# %% [markdown]
# ## Optics runs

# %%
df_optics = pd.read_csv('good_runList_GMn_nTPE_Optics_pass_2.csv')

# %%
# Convert each run number to a string
str_optics = map(str, df_optics['runnum'])
# Format correctly for bash arrays
print(' '.join(str_optics))
# Out:
# 11611 11614 11615 11616 11965 11966 11967 11968 11969 11972 11973 11976 11979 11980 11982 11984 11985 12278 12280 12281 12282 12283 13193 13194 13195 13196 13435 13436 13437 13439 13440 13444 13669 13671 13674 13675

# %% [markdown]
# ## Dummy runs

# %%
df_dummy = pd.read_csv('good_runList_GMn_nTPE_Dummy_pass_2.csv')

# %%
# Convert each run number to a string
str_dummy = map(str, df_dummy['runnum'])
# Format correctly for bash arrays
print(' '.join(str_dummy))
# Out:
# 11498 11572 11598 11599 12010 12036 12037 12054 12334 12397 12399 12489 12490 12560 12624 12690 12745 12821 12922 13001 13026 13064 13310 13311 13374 13404 13457 13458 13507 13508 13509 13513 13514 13658 13659 13794
