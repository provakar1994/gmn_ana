# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df = pd.read_csv("pdout/sysstdy/vary_W_rs_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/fits/sbs7sbs85p/sysstdy/vary_W_rs_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/fits/sbs7sbs85p/sysstdy/vary_dy_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/fits/sbs7sbs85p/sysstdy/vary_coinT_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/fits/sbs7sbs85p/sysstdy/vary_fidu_xy_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)

#df = pd.read_csv("pdout/fits/sbs11sbs100p/sysstdy/vary_fidu_xy_1p0sf_fit_dx_qelas_pass2_simc_sbs11_sbs100p_model2.csv", index_col=False)
df = pd.read_csv("pdout/fits/sbs11sbs100p/sysstdy/varydy_effic_1p27zoff_0p97sf_fit_dx_qelas_pass2_simc_sbs11_sbs100p_model2.csv", index_col=False)

#df = pd.read_csv("pdout/fits/sbs14sbs70p/sysstdy/vary_W_0p674sf_fit_dx_qelas_pass2_simc_sbs14_sbs70p_model2.csv", index_col=False)

#df = pd.read_csv("pdout/fits/sbs9sbs70p/sysstdy/new_vary_W2_0p7zoff_0p657sf_fit_dx_qelas_pass2_simc_sbs9_sbs70p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/fits/sbs9sbs70p/sysstdy/vary_dy_0p7zoff_0p657sf_fit_dx_qelas_pass2_simc_sbs9_sbs70p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/fits/sbs9sbs70p/sysstdy/vary_eHCAL_0p7zoff_0p657sf_fit_dx_qelas_pass2_simc_sbs9_sbs70p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/fits/sbs9sbs70p/sysstdy/vary_coinT_0p7zoff_0p657sf_fit_dx_qelas_pass2_simc_sbs9_sbs70p_model2.csv", index_col=False)

#df = pd.read_csv("pdout/sysstdy/vary_dy_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/sysstdy/vary_yHCAL_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/sysstdy/vary_yHCAL_w_dyCut_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/sysstdy/vary_eHCAL_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/sysstdy/vary_W_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/sysstdy/v2_vary_W_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)
#df = pd.read_csv("pdout/sysstdy/vary_W_0p65sf_fit_dx_qelas_pass2_simc_sbs4_sbs50p_model2.csv", index_col=False)
df.head()
# Out:
#                  cut  min  max     RMCnf  RMCnferr      RpMC   chi20  NDF0  \
# 0  -0.600<dy<=-0.500 -0.6 -0.5  0.378563  0.008334  0.394858  2727.6    62
# 1  -0.500<dy<=-0.400 -0.5 -0.4  0.380301  0.007422  0.394858  3173.2    62
# 2  -0.400<dy<=-0.300 -0.4 -0.3  0.384045  0.006166  0.394858  3415.1    62
# 3  -0.300<dy<=-0.200 -0.3 -0.2  0.380158  0.004567  0.394858  4438.4    62
# 4  -0.200<dy<=-0.100 -0.2 -0.1  0.390665  0.003259  0.394858  5156.6    62
#
#        R0   R0err  ...   R6err   B6  B6err   Yp6  Yp6err  Yn6  Yn6err  Ybg6  \
# 0  1.7404  0.0689  ...  0.2674  0.0    0.0   367      19   -8     NaN     0
# 1  1.6220  0.0621  ...  0.2051  0.0    0.0   479      22   57     8.0     0
# 2  1.6676  0.0576  ...  0.4244  0.0    0.0   355      19  181    13.0     1
# 3  1.4117  0.0432  ...  0.0845  0.0    0.0  1311      36  377    19.0     0
# 4  1.2672  0.0331  ...  0.0000  0.0    0.0  2558      51  791    28.0     1
#
#    Ybg6err  Unnamed: 82
# 0        1          NaN
# 1        1          NaN
# 2        1          NaN
# 3        1          NaN
# 4        1          NaN
#
# [5 rows x 83 columns]

# %%
# plotting various parameters vs cut width
plt.style.use('default')
sns.set_context('talk')
fig, ax = plt.subplots()
#fig.set_size_inches(12, 9)

#ax.plot(xlab, df_wcut_scan['R1'], marker='o', linestyle='--', color='b')
ax.errorbar(df['cut'], df['R1'], yerr=df['R1err'], marker='o', linestyle='', color='b', alpha=0.8, label='Data bg')
ax.errorbar(df['cut'], df['R2'], yerr=df['R2err'], marker='o', linestyle='', color='r', alpha=0.8, label='MC bg')
ax.errorbar(df['cut'], df['R3'], yerr=df['R3err'], marker='o', linestyle='', color='g', alpha=0.8, label='Poly (2) bg')
#ax.errorbar(df['cut'], df['R4'], yerr=df['R4err'], marker='o', linestyle='', color='m', alpha=0.8, label='Gaus bg')

ax.set_ylim(0.8,1.15)
#ax.set_ylim(0.9,1.2)
#ax.set_ylim(0.55,1.4)
#ax.set_ylim(0.1,1.8)
#ax.set_ylim(0,2)
#ax.set_ylim(0.8,1.05)
#ax.set_ylim(0.85,1.1)
ax.set_ylabel('R')
ax.grid(axis = "y")
#ax.set_title('W cut scan (w/ fidu. cut) | SBS4-SBS50% data')

fig.suptitle(r'dy cut scan | Q$^2$ = 4.5 GeV$^2$ data')

plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
# Plotting signal to bg as well
plt.style.use('default')
#sns.set_context('talk')
fig, ax = plt.subplots(2, 1, figsize=(7, 6), sharex=True, gridspec_kw={'height_ratios': [1.5, 1]})
#fig.set_size_inches(10, 7)

#ax.plot(xlab, df_wcut_scan['R1'], marker='o', linestyle='--', color='b')
ax[0].errorbar(df['cut'], df['R1'], yerr=df['R1err'], marker='o', linestyle='', color='b', alpha=0.8, label='Data bg')
#ax[0].errorbar(df['cut'], df['R2'], yerr=df['R2err'], marker='o', linestyle='', color='r', alpha=0.8, label='MC bg')
ax[0].errorbar(df['cut'], df['R3'], yerr=df['R3err'], marker='o', linestyle='', color='g', alpha=1, label='Poly (2) bg')
ax[0].errorbar(df['cut'], df['R4'], yerr=df['R4err'], marker='o', linestyle='', color='m', alpha=0.4, label='Gaus bg')
ax[0].errorbar(df['cut'], df['R5'], yerr=df['R5err'], marker='o', linestyle='', color='r', alpha=0.8, label='Poly (4) bg')


#ax[1].plot(df['cut'], (df['Yp2']+df['Yn2'])/(df['Yp2']+df['Yn2']+df['Ybg2']), marker='o', linestyle='', color='g', alpha=0.8, label='Sig')
#ax[1].plot(df['cut'], df['Ybg2']/(df['Yp2']+df['Yn2']+df['Ybg2']), marker='o', linestyle='', color='r', alpha=0.8, label='Bg')
ax[1].plot(df['cut'], (df['Yp3']+df['Yn3'])/(df['Yp3']+df['Yn3']+df['Ybg3']), marker='o', linestyle='', color='g', alpha=0.8, label='Sig')
ax[1].plot(df['cut'], df['Ybg3']/(df['Yp3']+df['Yn3']+df['Ybg3']), marker='o', linestyle='', color='r', alpha=0.8, label='Bg')

ax[0].set_ylim(-1,1.4)
#ax[0].set_ylim(0.8,1.17)
#ax[0].set_ylim(-1,1.5)
#ax[0].set_ylim(0.4,1.4)
#ax[0].set_ylim(0.95,1.1)
#ax.set_ylim(0.85,1.1)
ax[0].set_ylabel('R')
ax[0].grid(axis = "y")
ax[0].legend(loc='upper right')
ax[0].set_title('W2 cut scan | SBS9-SBS70% data')

ax[1].set_ylabel('Norm. Yields')
ax[1].grid(axis = "y")


#plt.tight_layout()

# Remove spacing between subplots
plt.subplots_adjust(hspace=0, wspace=0)

#fig.suptitle('W cut scan | SBS7-SBS85% data')

plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
# Plotting signal to bg as well
plt.style.use('default')
#sns.set_context('talk')
fig, ax = plt.subplots(2, 1, figsize=(7, 6), sharex=True, gridspec_kw={'height_ratios': [1.5, 1]})
#fig.set_size_inches(10, 7)

#ax.plot(xlab, df_wcut_scan['R1'], marker='o', linestyle='--', color='b')
ax[0].errorbar(df['cut'], df['R1']*df['RpMC'], yerr=df['R1err']*df['RpMC'], marker='o', linestyle='', color='b', alpha=0.8, label='Data bg')
ax[0].errorbar(df['cut'], df['R2']*df['RpMC'], yerr=df['R2err']*df['RpMC'], marker='o', linestyle='', color='r', alpha=0.8, label='MC bg')
ax[0].errorbar(df['cut'], df['R3']*df['RpMC'], yerr=df['R3err']*df['RpMC'], marker='o', linestyle='', color='g', alpha=0.8, label='Poly bg')
ax[0].errorbar(df['cut'], df['RMCnf'], yerr=df['RMCnferr'], marker='s', linestyle='', color='c', alpha=0.8, label='QE MC')

ax[1].plot(df['cut'], (df['Yp2']+df['Yn2'])/(df['Yp2']+df['Yn2']+df['Ybg2']), marker='o', linestyle='', color='g', alpha=0.8, label='Sig')
ax[1].plot(df['cut'], df['Ybg2']/(df['Yp2']+df['Yn2']+df['Ybg2']), marker='o', linestyle='', color='r', alpha=0.8, label='Bg')
#ax[1].plot(df['cut'], (df['Yp3']+df['Yn3'])/(df['Yp3']+df['Yn3']+df['Ybg3']), marker='o', linestyle='', color='g', alpha=0.8, label='Sig')
#ax[1].plot(df['cut'], df['Ybg3']/(df['Yp3']+df['Yn3']+df['Ybg3']), marker='o', linestyle='', color='r', alpha=0.8, label='Bg')

ax[0].set_ylim(0.3,0.42)
#ax[0].set_ylim(0.55,1.4)
#ax[0].set_ylim(0,0.55)
#ax[0].set_ylim(0.34,0.42)
#ax.set_ylim(0.8,1.05)
#ax.set_ylim(0.85,1.1)
ax[0].set_ylabel('Yield Ratio')
ax[0].grid(axis = "y")
ax[0].legend(loc='upper right')
ax[0].set_title('W2 cut scan | SBS9-SBS70% data')

ax[1].set_ylabel('Norm. Yields')
ax[1].grid(axis = "y")


#plt.tight_layout()

# Remove spacing between subplots
plt.subplots_adjust(hspace=0, wspace=0)

#fig.suptitle('W cut scan | SBS7-SBS85% data')

plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
# R_MC & R_data comparison
plt.style.use('default')
sns.set_context('talk')
fig, ax = plt.subplots()
fig.set_size_inches(10,7)

ax.errorbar(df['cut'], df['R2']*df['RpMC'], yerr=df['R2err']*df['RpMC'], marker='o', linestyle='', color='r', alpha=0.8, label='R (data)')
ax.errorbar(df['cut'], df['RMCnf'], yerr=df['RMCnferr'], marker='o', linestyle='', color='g', alpha=0.8, label='R (MC)')

axt = ax.twinx()
axt.errorbar(df['cut'], df['B2'], yerr=df['B2err'], marker='o', linestyle='', color='b', alpha=0.8, label='Bg')


ax.set_ylim(0.2,0.45)
ax.set_ylabel('R')
ax.grid(axis = "y")
ax.set_xticklabels(df['cut'], rotation=90)
#ax.set_title('W cut scan (w/ fidu. cut) | SBS4-SBS50% data')

ax.legend(loc="upper left")
axt.legend()

fig.suptitle('W cut scan | SBS7-SBS85% data')

plt.xticks(rotation=90)
#plt.legend()
plt.show()
# Out:
# /scratch/slurm/19425847/ipykernel_71133/4270113527.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df['cut'], rotation=90)

# %% [markdown]
# ## Fiducial Cut Variation

# %%
#df = pd.read_csv("pdout/sysstdy/vary_fidu_xy_0p815sf_fit_dx_qelas_pass2_simc_sbs7_sbs85p_model2.csv", index_col=False)

df = pd.read_csv("pdout/fits/sbs9sbs70p/sysstdy/vary_fidu_xy_0p7zoff_0p657sf_fit_dx_qelas_pass2_simc_sbs9_sbs70p_model2.csv", index_col=False)

df.head()
# Out:
#     cut   min   max     RMCnf  RMCnferr      RpMC    chi20  NDF0      R0  \
# 0  -20%  0.05  0.15  0.348008  0.001450  0.365018  13531.3   238  1.1464
# 1  -10%  0.05  0.15  0.347949  0.001485  0.365018  13208.1   238  1.1467
# 2    0%  0.05  0.15  0.348120  0.001528  0.365018  13231.9   238  1.1470
# 3  +10%  0.05  0.15  0.347475  0.001577  0.365018  13035.2   238  1.1490
# 4  +20%  0.05  0.15  0.347044  0.001640  0.365018  12480.8   238  1.1513
#
#     R0err  ...   R5err        B5   B5err     Yp5  Yp5err     Yn5  Yn5err  \
# 0  0.0024  ...  0.0029  316.5763  7.0482  836771    2430  316394     945
# 1  0.0024  ...  0.0030  307.7111  6.9675  799452    2378  301756     923
# 2  0.0025  ...  0.0031  297.9105  6.8010  756263    2314  285408     898
# 3  0.0026  ...  0.0032  286.0596  6.6274  708992    2242  266897     868
# 4  0.0027  ...  0.0033  262.0475  6.4730  655502    2158  247091     837
#
#     Ybg5  Ybg5err  Unnamed: 70
# 0  70623        2          NaN
# 1  68731        2          NaN
# 2  67109        2          NaN
# 3  64284        2          NaN
# 4  60201        2          NaN
#
# [5 rows x 71 columns]

# %%
# add sigma to the entries of cut column
#df['cut'] = df['cut'].apply(lambda x: str(x) + ' sigma')

# %%
# plotting various parameters vs cut width
plt.style.use('default')
sns.set_context('talk')
fig, ax = plt.subplots()
#fig.set_size_inches(12, 9)

#ax.plot(xlab, df_wcut_scan['R1'], marker='o', linestyle='--', color='b')
#ax.errorbar(df['cut'], df['R1'], yerr=df['R1err'], marker='o', linestyle='', color='b', alpha=0.8, label='Data bg')
#ax.errorbar(df['cut'], df['R2'], yerr=df['R2err'], marker='o', linestyle='', color='r', alpha=0.8, label='MC bg')
ax.errorbar(df['cut'], df['R3'], yerr=df['R3err'], marker='o', linestyle='', color='g', alpha=0.8, label='Poly (2) bg')
#ax.errorbar(df['cut'], df['R4'], yerr=df['R4err'], marker='o', linestyle='', color='m', alpha=0.8, label='Gaus bg')
ax.errorbar(df['cut'], df['R5'], yerr=df['R5err'], marker='o', linestyle='', color='m', alpha=0.8, label='Poly (4) bg')

#ax.set_ylim(-1,1.4)
#ax.set_ylim(0.55,1.4)
#ax.set_ylim(0.1,1.8)
#ax.set_ylim(0,2)
#ax.set_ylim(0.9,1.15)
ax.set_ylim(1.07,1.1)
ax.set_ylabel('R')
ax.grid(axis = "y")
#ax.set_title('W cut scan (w/ fidu. cut) | SBS4-SBS50% data')

fig.suptitle('Fiducial Cut Scan | In both X & Y')
#fig.suptitle('Fiducial Cut Scan | In Y')

plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
df_tmp = pd.read_csv("pdout/fits/sbs7sbs85p/temp.csv", index_col=False)

# %%
df_tmp.head()
# Out:
#      bg       R    Rerr
# 0  Data  1.0382  0.0307
# 1    MC  1.0586  0.0298
# 2  Poly  1.0459  0.0322

# %% [markdown]
# ## Getting the weighted mean of the R_fit

# %%
from scipy.optimize import curve_fit

# %%
# Define the model function for a constant
def constant_model(x, c):
    return c

# %%
# plotting various parameters vs cut width
plt.style.use('default')
#sns.set_context('talk')
fig, ax = plt.subplots()
#fig.set_size_inches(12, 9)

#ax.plot(xlab, df_wcut_scan['R1'], marker='o', linestyle='--', color='b')
ax.errorbar(df['bg'], df['R'], yerr=df['Rerr'], marker='o', linestyle='', color='b', alpha=0.8)

#ax.set_ylim(-1,1.4)
#ax.set_ylim(0.55,1.4)
#ax.set_ylim(0.1,1.8)
#ax.set_ylim(0,2)
#ax.set_ylim(0.9,1.15)
ax.set_ylim(0.95,1.15)
ax.set_ylabel('R')
ax.grid(axis = "y")
#ax.set_title('W cut scan (w/ fidu. cut) | SBS4-SBS50% data')

#fig.suptitle('Fiducial Cut Scan | In both X & Y')
#fig.suptitle('Fiducial Cut Scan | In Y')

plt.xticks(rotation=90)
#plt.legend()
plt.show()

# %% [markdown]
# # Vary Range

# %%
df = pd.read_csv("pdout/fits/sbs9sbs70p/vary_range_0p7zoff_0p657sf_fit_dx_qelas_pass2_simc_sbs9_sbs70p_model2.csv", index_col=False)

df.head()
# Out:
#   cut  min  max     RMCnf  RMCnferr      RpMC    chi20  NDF0      R0   R0err  \
# 0  R2 -1.6  0.6  0.348105  0.001531  0.365018   7318.7   238  1.1398  0.0025
# 1  R3 -1.7  0.7  0.348047  0.001529  0.365018  10113.1   238  1.1438  0.0025
# 2  R0 -1.8  0.8  0.348120  0.001528  0.365018  13231.9   238  1.1470  0.0025
# 3  R4 -1.9  0.9  0.348117  0.001527  0.365018  16224.5   238  1.1476  0.0025
# 4  R1 -2.0  1.0  0.348086  0.001527  0.365018  19061.0   238  1.1482  0.0025
#
#    ...   R5err        B5   B5err     Yp5  Yp5err     Yn5  Yn5err   Ybg5  \
# 0  ...  0.0038  226.9378  8.4426  752583    2307  286052     902  57353
# 1  ...  0.0033  256.2902  7.4473  755439    2313  286252     901  61623
# 2  ...  0.0031  297.9105  6.8010  756263    2314  285408     898  67109
# 3  ...  0.0029  332.2773  6.2996  756525    2314  284919     896  72022
# 4  ...  0.0028  363.7226  5.8386  755799    2312  284608     895  76736
#
#    Ybg5err  Unnamed: 70
# 0        2          NaN
# 1        2          NaN
# 2        2          NaN
# 3        2          NaN
# 4        2          NaN
#
# [5 rows x 71 columns]

# %%
# xlabels
xlab = ['({},{})'.format(row['min'],row['max']) for index, row in df.iterrows()]
xlab
# Out:
# ['(-1.6,0.6)', '(-1.7,0.7)', '(-1.8,0.8)', '(-1.9,0.9)', '(-2.0,1.0)']

# %%
# plotting various parameters vs cut width
plt.style.use('default')
sns.set_context('talk')
fig, ax = plt.subplots()
#fig.set_size_inches(12, 9)

#ax.plot(xlab, df_wcut_scan['R1'], marker='o', linestyle='--', color='b')
ax.errorbar(xlab, df['R1'], yerr=df['R1err'], marker='o', linestyle='', color='b', alpha=0.8, label='Data bg')
#ax.errorbar(df['cut'], df['R2'], yerr=df['R2err'], marker='o', linestyle='', color='r', alpha=0.8, label='MC bg')
ax.errorbar(xlab, df['R3'], yerr=df['R3err'], marker='o', linestyle='', color='g', alpha=0.8, label='Poly (2) bg')
ax.errorbar(xlab, df['R4'], yerr=df['R4err'], marker='o', linestyle='', color='m', alpha=0.8, label='Gaus bg')
ax.errorbar(xlab, df['R5'], yerr=df['R5err'], marker='o', linestyle='', color='y', alpha=0.8, label='Poly (4) bg')

#ax.set_ylim(-1,1.4)
#ax.set_ylim(0.55,1.4)
#ax.set_ylim(0.1,1.8)
#ax.set_ylim(0,2)
#ax.set_ylim(0.9,1.15)
ax.set_ylim(1.06,1.1)
ax.set_ylabel('R')
ax.set_xlabel(r'$\Delta$x Fit Range')
ax.grid(axis = "y")
#ax.set_title('W cut scan (w/ fidu. cut) | SBS4-SBS50% data')

fig.suptitle('Varying Fit Range')
#fig.suptitle('Fiducial Cut Scan | In Y')

plt.xticks(rotation=90)
plt.legend()
plt.show()
